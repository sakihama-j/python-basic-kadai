# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def print_info(self):
    print(f"名前:{self.name},年齢:{self.age}")

jay = Human("ジェイニー", 23)

jay.print_info()
