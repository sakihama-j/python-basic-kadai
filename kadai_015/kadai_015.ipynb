# %%
class Human:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def printinfo(self):
    print(f"{self.name},{self.age}")

jay = Human("ジェイニー", 23)

jay.printinfo()
# Out:
# ジェイニー,23
